# %%
# %%bash
# # download data
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_1.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_2.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_3.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_4.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_5.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_6.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_7.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_8.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2017_9.zip -b
#
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_1.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_2.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_3.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_4.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_5.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_6.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_7.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_8.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_9.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_10.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_11.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2016_12.zip -b

# %%
# %%bash
#
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_1.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_2.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_3.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_4.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_5.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_6.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_7.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_8.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_9.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_10.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_11.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2015_12.zip -b
#
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_1.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_2.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_3.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_4.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_5.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_6.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_7.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_8.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_9.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_10.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_11.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2014_12.zip -b
#
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_1.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_2.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_3.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_4.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_5.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_6.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_7.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_8.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_9.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_10.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_11.zip -b
# wget https://transtats.bts.gov/PREZIP/On_Time_On_Time_Performance_2013_12.zip -b
# Out:
# Continuing in background, pid 1936.
# Output will be written to ‘wget-log’.
# Continuing in background, pid 1938.
# Output will be written to ‘wget-log.1’.
# Continuing in background, pid 1940.
# Output will be written to ‘wget-log.2’.
# Continuing in background, pid 1942.
# Output will be written to ‘wget-log.3’.
# Continuing in background, pid 1944.
# Output will be written to ‘wget-log.4’.
# Continuing in background, pid 1947.
# Output will be written to ‘wget-log.5’.
# Continuing in background, pid 1949.
# Output will be written to ‘wget-log.6’.
# Continuing in background, pid 1951.
# Output will be written to ‘wget-log.7’.
# Continuing in background, pid 1953.
# Output will be written to ‘wget-log.8’.
# Continuing in background, pid 1955.
# Output will be written to ‘wget-log.9’.
# Continuing in background, pid 1957.
# Output will be written to ‘wget-log.10’.
# Continuing in background, pid 1959.
# Output will be written to ‘wget-log.11’.
# Continuing in background, pid 1961.
# ...

# %%
# %%bash
# # unzip all the compress files to zip
#
# unzip -o '*.zip' -d ./data ;
# Out:
# Archive:  On_Time_On_Time_Performance_2014_3.zip
#   inflating: ./data/On_Time_On_Time_Performance_2014_3.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2014_1.zip
#   inflating: ./data/On_Time_On_Time_Performance_2014_1.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2016_10.zip
#   inflating: ./data/On_Time_On_Time_Performance_2016_10.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2017_9.zip
#   inflating: ./data/On_Time_On_Time_Performance_2017_9.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2017_1.zip
#   inflating: ./data/On_Time_On_Time_Performance_2017_1.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2016_7.zip
#   inflating: ./data/On_Time_On_Time_Performance_2016_7.csv
#   inflating: ./data/readme.html
#
# Archive:  On_Time_On_Time_Performance_2017_5.zip
# ...

# %%
from IPython.display import display, HTML
import pandas
# data fields to keep:
# Year--Year 
# Quarter--Quarter (1-4)
# Month -- Month
# DayofMonth--Day of Month
# DayOfWeek -- Day of Week
# UniqueCarrier
# FlightNum
# OriginAirportID
# Origin
# DestAirportID
# Dest
# DepDelay -- Difference in minutes between scheduled and actual departure time. Early departures show negative numbers.
# ArrDelay -- Difference in minutes between scheduled and actual arrival time. Early arrivals show negative numbers.
# ArrTime -- Actual Arrival Time (local time: hhmm)
# DepTime -- Actual Departure Time (local time: hhmm)
# scheduled arrival time and departure time can be calcualted with actual time + delay delta. 
# there are Actual WheelsOn and WheelsOff time, but those are not practical to observe for a traveler
# AirTime -- Flight Time, in Minutes

# Distance -- Distance between airports (miles), OST_R divide distance by 250 to form groups
columns_to_keep = ["Year","Quarter","Month","DayofMonth","DayOfWeek","UniqueCarrier","FlightNum",
                   "OriginAirportID","Origin","Dest","DestAirportID","ArrTime","AirTime","Distance",
                   "DepDelay","ArrDelay","ArrTime","DepTime"
                  ]
data_2017_1 = pandas.read_csv("./data/On_Time_On_Time_Performance_2017_1.csv", low_memory=False)
data_2017_1 = data_2017_1[columns_to_keep]

data_2017 = pandas.concat([data_2017_1,pandas.read_csv("./data/On_Time_On_Time_Performance_2017_2.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_3.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_4.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_5.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_6.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_7.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_8.csv", low_memory=False)[columns_to_keep]])
data_2017 = pandas.concat([data_2017, pandas.read_csv("./data/On_Time_On_Time_Performance_2017_9.csv", low_memory=False)[columns_to_keep]])

# display(data_2017.head())
data_2017 = data_2017.dropna()
data_2017.to_csv("./data/processed/2017.csv")

data_2016_1 = pandas.read_csv("./data/On_Time_On_Time_Performance_2016_1.csv", low_memory=False)
data_2016_1 = data_2016_1[columns_to_keep]

data_2016 = pandas.concat([data_2016_1,pandas.read_csv("./data/On_Time_On_Time_Performance_2016_2.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_3.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_4.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_5.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_6.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_7.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_8.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_9.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_10.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_11.csv", low_memory=False)[columns_to_keep]])
data_2016 = pandas.concat([data_2016, pandas.read_csv("./data/On_Time_On_Time_Performance_2016_12.csv", low_memory=False)[columns_to_keep]])

data_2016 = data_2016.dropna()
data_2016.to_csv("./data/processed/2016.csv")

data_2015_1 = pandas.read_csv("./data/On_Time_On_Time_Performance_2015_1.csv", low_memory=False)
data_2015_1 = data_2015_1[columns_to_keep]

data_2015 = pandas.concat([data_2015_1,pandas.read_csv("./data/On_Time_On_Time_Performance_2015_2.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_3.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_4.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_5.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_6.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_7.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_8.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_9.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_10.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_11.csv", low_memory=False)[columns_to_keep]])
data_2015 = pandas.concat([data_2015, pandas.read_csv("./data/On_Time_On_Time_Performance_2015_12.csv", low_memory=False)[columns_to_keep]])

data_2015 = data_2015.dropna()
data_2015.to_csv("./data/processed/2015.csv")

data_2014_1 = pandas.read_csv("./data/On_Time_On_Time_Performance_2014_1.csv", low_memory=False)
data_2014_1 = data_2014_1[columns_to_keep]

data_2014 = pandas.concat([data_2014_1,pandas.read_csv("./data/On_Time_On_Time_Performance_2014_2.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_3.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_4.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_5.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_6.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_7.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_8.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_9.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_10.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_11.csv", low_memory=False)[columns_to_keep]])
data_2014 = pandas.concat([data_2014, pandas.read_csv("./data/On_Time_On_Time_Performance_2014_12.csv", low_memory=False)[columns_to_keep]])

data_2014 = data_2014.dropna()
data_2014.to_csv("./data/processed/2014.csv")

data_2013_1 = pandas.read_csv("./data/On_Time_On_Time_Performance_2013_1.csv", low_memory=False)
data_2013_1 = data_2013_1[columns_to_keep]

data_2013 = pandas.concat([data_2013_1,pandas.read_csv("./data/On_Time_On_Time_Performance_2013_2.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_3.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_4.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_5.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_6.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_7.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_8.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_9.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_10.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_11.csv", low_memory=False)[columns_to_keep]])
data_2013 = pandas.concat([data_2013, pandas.read_csv("./data/On_Time_On_Time_Performance_2013_12.csv", low_memory=False)[columns_to_keep]])

data_2013 = data_2013.dropna()
data_2013.to_csv("./data/processed/2013.csv")

# %%
data_2017=pandas.read_csv("./data/processed/2017.csv")
data_2016=pandas.read_csv("./data/processed/2016.csv")
data_2015=pandas.read_csv("./data/processed/2015.csv")
data_2014=pandas.read_csv("./data/processed/2014.csv")
data_2013=pandas.read_csv("./data/processed/2013.csv")
data = pandas.concat([data_2017, data_2016, data_2015, data_2014, data_2013])
data.to_csv("./data/processed/data_all.csv")
